# %%
import numpy as np
import matplotlib.pyplot as plt



X = ['Enc_local_model', 'Enc_global_model', 'Dec_global_model']
MNIST = [111.5, 84.5, 1.8 ]
F_MNIST = [192.1, 146.3, 0.549]

fig1, ax = plt.subplots()
X_axis = np.arange(len(X))
plt.grid(zorder=0)
plt.bar(X_axis - 0.2, MNIST, 0.4, zorder=3, hatch='*', edgecolor='black')
plt.bar(X_axis + 0.2, F_MNIST, 0.4, zorder=3, hatch='x', edgecolor='black')
fontsize = 10
for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(fontsize)
    tick.label1.set_fontweight('bold')
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(fontsize)
    tick.label1.set_fontweight('bold')
ax.spines['bottom'].set_color('grey')
ax.set_yscale('log')
ax.spines['top'].set_color('grey')
ax.spines['right'].set_color('grey')
ax.spines['left'].set_color('grey')
#plt.legend(loc=2, prop={'size': 10})
plt.xticks(X_axis, X, rotation=0)
plt.xlabel("Model Category", fontweight='bold', fontsize=12)
plt.ylabel("Data Size (MBs)", fontweight='bold', fontsize=12)
#plt.title("Number of Students in each group")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np

import pandas as pd 
import matplotlib.pyplot as plt
fig,ax = plt.subplots(figsize=(16,6))
dataDict = {'Year': ['1st Year','2st Year','3rd Year','4th Year'],
            'ERRh': [0, 0.71, 0.46, 0.35],
            'HRRh': [0.0, 0.66, 0.33, 0.14],
            'EREh': [0.0, 0.38, 0.20, 0.11],
            'ERRc': [1.2, 1.62, 2.04, 0.04],
            'HRRc': [1.36, 2.27, 4.83, 0.09],
            'EREc': [150, 120, 90, 70]}

# Create a dataframe
dfDataTest=pd.DataFrame.from_dict(dataDict, orient='columns', dtype=None, columns=None)
# Set Year column as index
dfDataTest.index = dfDataTest.Year 
# delete Year column
dfDataTest.drop('Year', inplace = True, axis=1) 


labels = dfDataTest.index.tolist()

x = np.arange(len(labels))
# Set the plotting settings 
plotStyleDict = {'axes.titlesize' : 18,
'axes.titleweight' :'bold',
'axes.labelsize' : 15,
'lines.linewidth' : 3,
'lines.markersize' : 10,
'xtick.labelsize' : 12,
'ytick.labelsize' : 12}
plt.style.use(plotStyleDict)


ax2 = ax.twinx()
ax3 = ax.twinx()

ax.set_xlim(-0.5, 4)
ax.set_ylim(0, 1)
ax2.set_ylim(0, 5)
ax3.set_ylim(0,160)

ax.set_xlabel('Year')
ax.set_ylabel(r'$\eta_{ER,h} , \eta_{HR,h}  , \eta_{th,h}   [-]$', size=18)
ax2.set_ylabel(r'$\eta_{ER,h} , \eta_{HR,h}  , \eta_{th,h}   [-]$', size=18)
ax3.set_ylabel(r'$\eta_{ER,c} , \eta_{HR,c}  , \eta_{th,c}  [-]$', size=18)

color=['firebrick','red','darksalmon','darkblue','blue','royalblue']
width = 0.1
p1 = ax.bar(x-(width*3), dfDataTest['ERRh'], width=width, color=color[0], align='center', label=r'$\eta_{ER,h}$')
p2 = ax.bar(x-(width*2), dfDataTest['HRRh'], width=width, color=color[1], align='center', label=r'$\eta_{ER,h}$')
p3 = ax.bar(x-width, dfDataTest['EREh'], width=width, color=color[2], align='center', label=r'$\eta_{ER,h}$')
p4 = ax2.bar(x, dfDataTest['ERRc'], width=width, color=color[3], align='center', label=r'$\eta_{HR,h}, \eta_{th,h}$')
p5 = ax2.bar(x+(width*1), dfDataTest['HRRc'], width=width, color=color[4], align='center', label=r'$\eta_{HR,h}, \eta_{th,h}$')
p6 = ax3.bar(x+(width*2), dfDataTest['EREc'], width=width, color=color[5], align='center', label=r'$\eta_{ER,c} , \eta_{HR,c}$')

lns = [p1,p2,p3,p4,p5,p6]
ax.legend(handles=lns, loc='best')

ax3.spines['right'].set_position(('outward', 60))  
ax3.xaxis.set_ticks([])

ax.set_xticks(x)
ax.set_xticklabels(labels)

ax.set_title("Energy & Hydraulic Recoveries for Heating and Cooling",fontsize=18, weight='bold')
ax3.set_ylabel(r'$\eta_{ER,c} , \eta_{HR,c}  , \eta_{th,c}  [-]$')
fig.show()
# Out:
# <ipython-input-7-5db389a519b6>:69: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
for p in ax.patches:
            if p.get_height() > 2:
                annotate_height = p.get_height()-22
            else:
                annotate_height = p.get_height()
            ax.annotate("%.2f" % p.get_height(), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=11, color='black', xytext=(0, 20),
                        textcoords='offset points')

# %%
FLNFTC_rinkeby
# Out:
# [4561494, 0.01140373504561494, 39.91307265965229]

# %%
X_axis
# Out:
# array([0, 1])

# %%
0.01794268757177075*3500
# Out:
# 62.79940650119763

# %%
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
import numpy as np
import matplotlib.pyplot as plt



X = ['FLNFTC', 'FLTPC']
FLNFTC_rinkeby = [4_561_494, 0.01140373504561494, 0.01140373504561494*3500 ] # GAS_USED, tx_fee, USD
FLTPC_rinkeby = [7_177_075, 0.01794268757177075, 0.01794268757177075*3500]
FLNFTC_ropsten = [10_561_494, 0.01540373504561494, 0.01540373504561494*3500 ] # GAS_USED, tx_fee, USD
FLTPC_ropsten = [21_177_075, 0.02094268757177075, 0.02094268757177075*3500]
GAS_USED_rinkeby = [FLNFTC_rinkeby[0], FLTPC_rinkeby[0]]
GAS_USED_ropsten = [FLNFTC_ropsten[0], FLTPC_ropsten[0]]
tx_fee_rinkeby = [FLNFTC_rinkeby[1], FLTPC_rinkeby[1]]
tx_fee_ropsten = [FLNFTC_ropsten[1], FLTPC_ropsten[1]]
usd_fee_rinkeby = [FLNFTC_rinkeby[2], FLTPC_rinkeby[2]]
usd_fee_ropsten = [FLNFTC_ropsten[2], FLTPC_ropsten[2]]

width = 0.125
fig1, ax1 = plt.subplots(figsize=(12,9))
ax1.set_ylabel('Gas Used', fontweight='bold', fontsize=12)
X_axis = np.arange(len(GAS_USED_rinkeby))

# plt.grid(zorder=0)

ax2 = ax1.twinx()
ax2.set_ylabel('Transaction fee ETH', fontweight='bold', fontsize=12)
ax3 = ax1.twinx()
ax3.set_ylabel('Transaction fee USD', fontweight='bold', fontsize=12)
ax3.spines['right'].set_position(('outward', 70))  
p1 = ax1.bar(X_axis-width*2.5, GAS_USED_rinkeby, width, zorder=3, hatch='*', edgecolor='black', color="green", label='Gas used Rinkeby')
p2 = ax1.bar(X_axis+width*0.5, GAS_USED_ropsten, width, zorder=3, hatch='*', edgecolor='black', color="brown", label='Gas used Ropsten')
p3 = ax2.bar(X_axis-width*1.5, tx_fee_rinkeby, width, zorder=3, hatch='x', edgecolor='black', color="blue", label='Transaction fee ETH Rinkeby')
p4 = ax2.bar(X_axis+width*1.5, tx_fee_ropsten, width, zorder=3, hatch='x', edgecolor='black', color="orange", label='Transaction fee ETH Ropsten')
p5 = ax3.bar(X_axis-width*0.5, usd_fee_rinkeby, width, zorder=3, hatch='o', edgecolor='black', color="teal", label='Transaction fee USD Rinkeby')
p6 = ax3.bar(X_axis+width*2.5, usd_fee_ropsten, width, zorder=3, hatch='o', edgecolor='black', color="cyan", label='Transaction fee USD Ropsten')
lns = [p1,p2,p3,p4,p5,p6]
ax1.legend(handles=lns, loc='best',fontsize=14)
ax3.set_xticks(X_axis)
ax3.set_xticklabels(X)
ax3.xaxis.set_ticks_position("bottom")
ax1.set_xlabel("Smart Contracts", fontweight='bold', fontsize=12)


plt.show()

# %%
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
import numpy as np
import matplotlib.pyplot as plt



X = ['FLNFTC', 'FLTPC']
FLNFTC_rinkeby = [4_561_494, 0.01140373504561494, 0.01140373504561494*3500 ] # GAS_USED, tx_fee, USD
FLTPC_rinkeby = [6_923_035, 0.006923035366920855, 0.01794268757177075*3500]
FLNFTC_ropsten = [4_561_494 , 0.01140373513684482, 0.01140373513684482*3500 ] # GAS_USED, tx_fee, USD
FLTPC_ropsten = [7_177_075, 0.017942687650718575, 0.017942687650718575*3500]
GAS_USED_rinkeby = [FLNFTC_rinkeby[0], FLTPC_rinkeby[0]]
GAS_USED_ropsten = [FLNFTC_ropsten[0], FLTPC_ropsten[0]]
tx_fee_rinkeby = [FLNFTC_rinkeby[1], FLTPC_rinkeby[1]]
tx_fee_ropsten = [FLNFTC_ropsten[1], FLTPC_ropsten[1]]
usd_fee_rinkeby = [FLNFTC_rinkeby[2], FLTPC_rinkeby[2]]
usd_fee_ropsten = [FLNFTC_ropsten[2], FLTPC_ropsten[2]]

width = 0.125
fig1, ax1 = plt.subplots(figsize=(12,10))
ax1.set_ylabel('Gas Used', fontweight='bold', fontsize=12)
X_axis = np.arange(len(GAS_USED_rinkeby))

# plt.grid(zorder=0)

ax2 = ax1.twinx()
ax2.set_ylabel('Transaction fee ETH', fontweight='bold', fontsize=12)
ax3 = ax1.twinx()
ax3.set_ylabel('Transaction fee USD', fontweight='bold', fontsize=12)
ax3.spines['right'].set_position(('outward', 70))  
p1 = ax1.bar(X_axis-width*2.5, GAS_USED_rinkeby, width, zorder=3, hatch='*', edgecolor='black', color="green", label='Gas used Rinkeby')
# for p in ax1.patches:    
#     annotate_height = p.get_height()
#     ax1.annotate("{:.1e}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
#                         ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
# print(p.get_height(),' ', p.get_x(),' ', p.get_width() )

p2 = ax1.bar(X_axis+width*0.5, GAS_USED_ropsten, width, zorder=3, hatch='*', edgecolor='black', color="brown", label='Gas used Ropsten')
for p in ax1.patches:    
    annotate_height = p.get_height()-2e5
    ax1.annotate("{:.1e}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
p3 = ax2.bar(X_axis-width*1.5, tx_fee_rinkeby, width, zorder=3, hatch='x', edgecolor='black', color="green", label='Transaction fee ETH Rinkeby')
p4 = ax2.bar(X_axis+width*1.5, tx_fee_ropsten, width, zorder=3, hatch='x', edgecolor='black', color="brown", label='Transaction fee ETH Ropsten')
for p in ax2.patches:    
    annotate_height = p.get_height()-0.0005
    ax2.annotate("{:.3f}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')

p5 = ax3.bar(X_axis-width*0.5, usd_fee_rinkeby, width, zorder=3, hatch='o', edgecolor='black', color="green", label='Transaction fee USD Rinkeby')
p6 = ax3.bar(X_axis+width*2.5, usd_fee_ropsten, width, zorder=3, hatch='o', edgecolor='black', color="brown", label='Transaction fee USD Ropsten')
for p in ax3.patches:    
    annotate_height = p.get_height()-1.5
    ax3.annotate("{:.2f}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
lns = [p1,p2,p3,p4,p5,p6]
ax1.legend(handles=lns, loc='best',fontsize=14)
ax3.set_xticks(X_axis)
ax3.set_xticklabels(X)
ax3.xaxis.set_ticks_position("bottom")
ax1.set_xlabel("Smart Contracts", fontweight='bold', fontsize=12)


plt.show()

# %%
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
import numpy as np
import matplotlib.pyplot as plt



X = ['FLNFTC', 'FLTPC']
FLNFTC_rinkeby = [4_349_720, 1.000000053,0.00434972023053516. 0.00434972023053516*3250 ] # GAS_USED, tx_fee, USD
FLTPC_rinkeby = [6_923_035, 1.000000053, 0.006923035366920855, 0.00692303536692085*3250]
FLNFTC_ropsten = [4_349_720 , 2.500000027,0.010874300108743, 0.010874300108743*3250 ] # GAS_USED, tx_fee, USD
FLTPC_ropsten = [6_923_035, 2.500000027, 0.017307587686921945, 0.017307587686921945*3250]
GAS_USED_rinkeby = [FLNFTC_rinkeby[0], FLTPC_rinkeby[0]]
GAS_USED_ropsten = [FLNFTC_ropsten[0], FLTPC_ropsten[0]]
tx_fee_rinkeby = [FLNFTC_rinkeby[1], FLTPC_rinkeby[1]]
tx_fee_ropsten = [FLNFTC_ropsten[1], FLTPC_ropsten[1]]
usd_fee_rinkeby = [FLNFTC_rinkeby[2], FLTPC_rinkeby[2]]
usd_fee_ropsten = [FLNFTC_ropsten[2], FLTPC_ropsten[2]]

width = 0.125
fig1, ax1 = plt.subplots(figsize=(12,10))
ax1.set_ylabel('Gas Used', fontweight='bold', fontsize=12)
X_axis = np.arange(len(GAS_USED_rinkeby))

# plt.grid(zorder=0)

ax2 = ax1.twinx()
ax2.set_ylabel('Transaction fee ETH', fontweight='bold', fontsize=12)
ax3 = ax1.twinx()
ax3.set_ylabel('Transaction fee USD', fontweight='bold', fontsize=12)
ax3.spines['right'].set_position(('outward', 70))  
p1 = ax1.bar(X_axis-width*2.5, GAS_USED_rinkeby, width, zorder=3, hatch='*', edgecolor='black', color="green", label='Gas used Rinkeby')
# for p in ax1.patches:    
#     annotate_height = p.get_height()
#     ax1.annotate("{:.1e}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
#                         ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
# print(p.get_height(),' ', p.get_x(),' ', p.get_width() )

p2 = ax1.bar(X_axis+width*0.5, GAS_USED_ropsten, width, zorder=3, hatch='*', edgecolor='black', color="brown", label='Gas used Ropsten')
for p in ax1.patches:    
    annotate_height = p.get_height()-2e5
    ax1.annotate("{:.1e}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
p3 = ax2.bar(X_axis-width*1.5, tx_fee_rinkeby, width, zorder=3, hatch='x', edgecolor='black', color="green", label='Transaction fee ETH Rinkeby')
p4 = ax2.bar(X_axis+width*1.5, tx_fee_ropsten, width, zorder=3, hatch='x', edgecolor='black', color="brown", label='Transaction fee ETH Ropsten')
for p in ax2.patches:    
    annotate_height = p.get_height()-0.0005
    ax2.annotate("{:.3f}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')

p5 = ax3.bar(X_axis-width*0.5, usd_fee_rinkeby, width, zorder=3, hatch='o', edgecolor='black', color="green", label='Transaction fee USD Rinkeby')
p6 = ax3.bar(X_axis+width*2.5, usd_fee_ropsten, width, zorder=3, hatch='o', edgecolor='black', color="brown", label='Transaction fee USD Ropsten')
for p in ax3.patches:    
    annotate_height = p.get_height()-1.5
    ax3.annotate("{:.2f}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
lns = [p1,p2,p3,p4,p5,p6]
ax1.legend(handles=lns, loc='best',fontsize=14)
ax3.set_xticks(X_axis)
ax3.set_xticklabels(X)
ax3.xaxis.set_ticks_position("bottom")
ax1.set_xlabel("Smart Contracts", fontweight='bold', fontsize=12)


plt.show()

# %%
# orig
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
import numpy as np
import matplotlib.pyplot as plt



X = ['FLNFTC', 'FLTPC']
FLNFTC_rinkeby = [4_349_720, 0.00434972023053516, 0.00434972023053516*3250 ] # GAS_USED, tx_fee, USD
FLTPC_rinkeby = [6_923_035,  0.006923035366920855, 0.00692303536692085*3250]
FLNFTC_ropsten = [4_349_720, 0.010874300108743, 0.010874300108743*3250 ] # GAS_USED, tx_fee, USD
FLTPC_ropsten = [6_923_035,  0.017307587686921945, 0.017307587686921945*3250]
GAS_USED_rinkeby = [FLNFTC_rinkeby[0], FLTPC_rinkeby[0]]
GAS_USED_ropsten = [FLNFTC_ropsten[0], FLTPC_ropsten[0]]
tx_fee_rinkeby = [FLNFTC_rinkeby[1], FLTPC_rinkeby[1]]
tx_fee_ropsten = [FLNFTC_ropsten[1], FLTPC_ropsten[1]]
usd_fee_rinkeby = [FLNFTC_rinkeby[2], FLTPC_rinkeby[2]]
usd_fee_ropsten = [FLNFTC_ropsten[2], FLTPC_ropsten[2]]

width = 0.125
fig1, ax1 = plt.subplots(figsize=(12,10))
ax1.set_ylabel('Gas Used', fontweight='bold', fontsize=12)
X_axis = np.arange(len(GAS_USED_rinkeby))

# plt.grid(zorder=0)

ax2 = ax1.twinx()
ax2.set_ylabel('Transaction fee (ETH)', fontweight='bold', fontsize=12)
ax3 = ax1.twinx()
ax3.set_ylabel('Transaction fee (USD)', fontweight='bold', fontsize=12)
ax3.spines['right'].set_position(('outward', 70))  
p1 = ax1.bar(X_axis-width*2.5, GAS_USED_rinkeby, width, zorder=3, hatch='*', edgecolor='black', color="green", label='Gas used Rinkeby')
# for p in ax1.patches:    
#     annotate_height = p.get_height()
#     ax1.annotate("{:.1e}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
#                         ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
# print(p.get_height(),' ', p.get_x(),' ', p.get_width() )

p2 = ax1.bar(X_axis+width*0.5, GAS_USED_ropsten, width, zorder=3, hatch='*', edgecolor='black', color="brown", label='Gas used Ropsten')
for p in ax1.patches:    
    annotate_height = p.get_height()-2e5
    ax1.annotate("{:.1e}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
p3 = ax2.bar(X_axis-width*1.5, tx_fee_rinkeby, width, zorder=3, hatch='x', edgecolor='black', color="blue", label='Transaction fee - Rinkeby (ETH)')
p4 = ax2.bar(X_axis+width*1.5, tx_fee_ropsten, width, zorder=3, hatch='x', edgecolor='black', color="orange", label='Transaction fee - Ropsten (ETH)')
for p in ax2.patches:    
    annotate_height = p.get_height()-0.0005
    ax2.annotate("{:.3f}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')

p5 = ax3.bar(X_axis-width*0.5, usd_fee_rinkeby, width, zorder=3, hatch='o', edgecolor='black', color="teal", label='Transaction fee - Rinkeby (USD)')
p6 = ax3.bar(X_axis+width*2.5, usd_fee_ropsten, width, zorder=3, hatch='o', edgecolor='black', color="cyan", label='Transaction fee Ropsten (USD)')
for p in ax3.patches:    
    annotate_height = p.get_height()-1.5
    ax3.annotate("{:.2f}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
lns = [p1,p2,p3,p4,p5,p6]
ax1.legend(handles=lns, loc='best',fontsize=14)
ax3.set_xticks(X_axis)
ax3.set_xticklabels(X)
ax3.xaxis.set_ticks_position("bottom")
ax1.set_xlabel("Smart Contracts", fontweight='bold', fontsize=12)


plt.show()

# %%
# orig
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
import numpy as np
import matplotlib.pyplot as plt



X = ['FLNFTC', 'FLTPC']
FLNFTC_rinkeby = [4_349_720, 0.00434972023053516, 0.00434972023053516*3250 ] # GAS_USED, tx_fee, USD
FLTPC_rinkeby = [6_923_035,  0.006923035366920855, 0.00692303536692085*3250]
FLNFTC_ropsten = [4_349_720, 0.010874300108743, 0.010874300108743*3250 ] # GAS_USED, tx_fee, USD
FLTPC_ropsten = [6_923_035,  0.017307587686921945, 0.017307587686921945*3250]
GAS_USED_rinkeby = [FLNFTC_rinkeby[0], FLTPC_rinkeby[0]]
GAS_USED_ropsten = [FLNFTC_ropsten[0], FLTPC_ropsten[0]]
tx_fee_rinkeby = [FLNFTC_rinkeby[1], FLTPC_rinkeby[1]]
tx_fee_ropsten = [FLNFTC_ropsten[1], FLTPC_ropsten[1]]
usd_fee_rinkeby = [FLNFTC_rinkeby[2], FLTPC_rinkeby[2]]
usd_fee_ropsten = [FLNFTC_ropsten[2], FLTPC_ropsten[2]]

width = 0.125
fig1, ax1 = plt.subplots(figsize=(12,10))
ax1.set_ylabel('Gas Used', fontweight='bold', fontsize=12)
X_axis = np.arange(len(GAS_USED_rinkeby))

# plt.grid(zorder=0)

ax2 = ax1.twinx()
ax2.set_ylabel('Transaction fee (ETH)', fontweight='bold', fontsize=12)
ax3 = ax1.twinx()
ax3.set_ylabel('Transaction fee (USD)', fontweight='bold', fontsize=12)
ax3.spines['right'].set_position(('outward', 70))  
p1 = ax1.bar(X_axis-width*2.5, GAS_USED_rinkeby, width, zorder=3, hatch='/', edgecolor='black', color="green", label='Gas used Rinkeby')
# for p in ax1.patches:    
#     annotate_height = p.get_height()
#     ax1.annotate("{:.1e}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
#                         ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
# print(p.get_height(),' ', p.get_x(),' ', p.get_width() )

p2 = ax1.bar(X_axis+width*0.5, GAS_USED_ropsten, width, zorder=3, hatch='\\', edgecolor='black', color="brown", label='Gas used Ropsten')
for p in ax1.patches:    
    annotate_height = p.get_height()-2e5
    ax1.annotate("{:.1e}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
p3 = ax2.bar(X_axis-width*1.5, tx_fee_rinkeby, width, zorder=3, hatch='|', edgecolor='black', color="blue", label='Transaction fee - Rinkeby (ETH)')
p4 = ax2.bar(X_axis+width*1.5, tx_fee_ropsten, width, zorder=3, hatch='-', edgecolor='black', color="orange", label='Transaction fee - Ropsten (ETH)')
for p in ax2.patches:    
    annotate_height = p.get_height()-0.0005
    ax2.annotate("{:.3f}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')

p5 = ax3.bar(X_axis-width*0.5, usd_fee_rinkeby, width, zorder=3, hatch='x', edgecolor='black', color="teal", label='Transaction fee - Rinkeby (USD)')
p6 = ax3.bar(X_axis+width*2.5, usd_fee_ropsten, width, zorder=3, hatch='o', edgecolor='black', color="cyan", label='Transaction fee Ropsten (USD)')
for p in ax3.patches:    
    annotate_height = p.get_height()-1.5
    ax3.annotate("{:.2f}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
lns = [p1,p2,p3,p4,p5,p6]
ax1.legend(handles=lns, loc='best',fontsize=14)
ax3.set_xticks(X_axis)
ax3.set_xticklabels(X)
ax3.xaxis.set_ticks_position("bottom")
ax1.set_xlabel("Smart Contracts", fontweight='bold', fontsize=12)


plt.show()

# %%
# orig
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
import numpy as np
import matplotlib.pyplot as plt



X = ['FLNFTC', 'FLTPC']
FLNFTC_rinkeby = [4_349_720, 0.00434972023053516, 0.00434972023053516*3250 ] # GAS_USED, tx_fee, USD
FLTPC_rinkeby = [6_923_035,  0.006923035366920855, 0.00692303536692085*3250]
FLNFTC_ropsten = [4_349_720, 0.010874300108743, 0.010874300108743*3250 ] # GAS_USED, tx_fee, USD
FLTPC_ropsten = [6_923_035,  0.017307587686921945, 0.017307587686921945*3250]
GAS_USED_rinkeby = [FLNFTC_rinkeby[0], FLTPC_rinkeby[0]]
GAS_USED_ropsten = [FLNFTC_ropsten[0], FLTPC_ropsten[0]]
tx_fee_rinkeby = [FLNFTC_rinkeby[1], FLTPC_rinkeby[1]]
tx_fee_ropsten = [FLNFTC_ropsten[1], FLTPC_ropsten[1]]
usd_fee_rinkeby = [FLNFTC_rinkeby[2], FLTPC_rinkeby[2]]
usd_fee_ropsten = [FLNFTC_ropsten[2], FLTPC_ropsten[2]]

width = 0.125
fig1, ax1 = plt.subplots(figsize=(12,10))
ax1.set_ylabel('Gas Used', fontweight='bold', fontsize=12)
X_axis = np.arange(len(GAS_USED_rinkeby))

# plt.grid(zorder=0)

ax2 = ax1.twinx()
ax2.set_ylabel('Transaction fee (ETH)', fontweight='bold', fontsize=12)
ax3 = ax1.twinx()
ax3.set_ylabel('Transaction fee (USD)', fontweight='bold', fontsize=12)
ax3.spines['right'].set_position(('outward', 70))  
p1 = ax1.bar(X_axis-width*2.5, GAS_USED_rinkeby, 0.9*width, zorder=3, hatch='/', edgecolor='black', color="green", label='Gas used Rinkeby')
# for p in ax1.patches:    
#     annotate_height = p.get_height()
#     ax1.annotate("{:.1e}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
#                         ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
# print(p.get_height(),' ', p.get_x(),' ', p.get_width() )

p2 = ax1.bar(X_axis+width*0.5, GAS_USED_ropsten, 0.9*width, zorder=3, hatch='\\', edgecolor='black', color="brown", label='Gas used Ropsten')
for p in ax1.patches:    
    annotate_height = p.get_height()-2e5
    ax1.annotate("{:.1e}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
p3 = ax2.bar(X_axis-width*1.5, tx_fee_rinkeby, 0.9*width, zorder=3, hatch='|', edgecolor='black', color="blue", label='Transaction fee - Rinkeby (ETH)')
p4 = ax2.bar(X_axis+width*1.5, tx_fee_ropsten, 0.9*width, zorder=3, hatch='-', edgecolor='black', color="orange", label='Transaction fee - Ropsten (ETH)')
for p in ax2.patches:    
    annotate_height = p.get_height()-0.0005
    ax2.annotate("{:.3f}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')

p5 = ax3.bar(X_axis-width*0.5, usd_fee_rinkeby, 0.9*width, zorder=3, hatch='x', edgecolor='black', color="teal", label='Transaction fee - Rinkeby (USD)')
p6 = ax3.bar(X_axis+width*2.5, usd_fee_ropsten, 0.9*width, zorder=3, hatch='o', edgecolor='black', color="cyan", label='Transaction fee Ropsten (USD)')
for p in ax3.patches:    
    annotate_height = p.get_height()-1.5
    ax3.annotate("{:.2f}".format(p.get_height()).replace("e+0", "e"), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),textcoords='offset points')
lns = [p1,p2,p3,p4,p5,p6]
ax1.legend(handles=lns, loc='best',fontsize=14)
ax3.set_xticks(X_axis)
ax3.set_xticklabels(X)
ax3.xaxis.set_ticks_position("bottom")
ax1.set_xlabel("Smart Contracts", fontweight='bold', fontsize=12)


plt.show()

# %%
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
import numpy as np
import matplotlib.pyplot as plt


X_axis = np.arange(len(X))
X = ['Rinkeby', 'Ropsten']
Gas_Price = [1.000000053, 2.500000027] 


width = 0.8
fig1, ax1 = plt.subplots(figsize=(8,6))
ax1.set_ylabel('Gas Price (Gwei)', fontweight='bold', fontsize=12)
p1 = ax1.bar(0, Gas_Price[0], width, zorder=3, hatch='O', edgecolor='black', color="salmon", label='Gas Price - Rinkeby')
p2= ax1.bar(1, Gas_Price[1], width, zorder=3, hatch='.', edgecolor='black', color="wheat", label='Gas Price - Ropsten')
for p in ax1.patches:    
    annotate_height = p.get_height()-0.1
    ax1.annotate("{:.9f}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', fontsize=12, color='black', xytext=(0, 20),textcoords='offset points')

lns = [p1, p2]
ax1.legend(handles=lns, loc='best',fontsize=14)
ax1.set_xticks(X_axis)
ax1.set_xticklabels(X, fontsize=12)
ax1.xaxis.set_ticks_position("bottom")
ax1.set_xlabel("Network", fontweight='bold', fontsize=12)


plt.show()

# %%
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
import numpy as np
import matplotlib.pyplot as plt



X = ['createFLNFT', 'start_LMSs', 'submitLocalModel', 'close_LMSs','ADRLMS','setLMSADRC','GMupdate']
Gas_Used = [505_401, 60_683, 270_110, 66_038, 87133, 64_149, 175_107 ] 
Gas_Price = [2.000000234, 1.940000008, 2.1428571486, 2.000000256,1.5000000080, 2.500000008  , 1.440000204 ]
Tx_fee_eth = [0.001010802118263834, 0.000117725020485464, 0.0005872333 , 0.000122476015676928, 0.0001518631, 0.000160372500513192, 0.000252154115721828]
Tx_fee_usd = Tx_fee_usd = [m *3250 for m in Tx_fee_eth]


width = 0.2
fig1, ax1 = plt.subplots(figsize=(12,9))
ax1.set_ylabel('Gas Used', fontweight='bold', fontsize=12)
ax1.set_ylim(0,800000)
X_axis = np.arange(len(X))

p1 = ax1.bar(X_axis-width*1.5, Gas_Used, width, zorder=3, hatch='*', edgecolor='black', color="green", label='Gas Used')

for p in ax1.patches:    
    annotate_height = p.get_height()+20000
    ax1.annotate("{:.0f}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', rotation=90, fontsize=12, color='black', xytext=(0, 20),textcoords='offset points')
    
ax2 = ax1.twinx()  
# ax2.spines['left'].set_position(('outward', 70)) 
ax2.set_ylabel('Gas Price (Gwei)', fontweight='bold', fontsize=12)
ax2.set_ylim(1,3)

p2 = ax2.bar(X_axis-width*0.5, Gas_Price, width, zorder=3, hatch='O', edgecolor='black', color="salmon", label='Gas Price')

for p in ax2.patches:    
    annotate_height = p.get_height()+0.1
    ax2.annotate("{:.6f}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', rotation=90, fontsize=12, color='black', xytext=(0, 20),textcoords='offset points')
    
ax3 = ax1.twinx()
ax3.set_ylabel('Transaction fee (ETH)', fontweight='bold', fontsize=12)
ax4 = ax1.twinx()
ax4.set_ylabel('Transaction fee (USD)', fontweight='bold', fontsize=12)
ax3.spines['right'].set_position(('outward', 70))  
ax4.spines['right'].set_position(('outward', 150))  
p3 = ax3.bar(X_axis+width*0.5, Tx_fee_eth, width, zorder=3, hatch='x', edgecolor='black', color="blue", label='Transaction fee (ETH)')
ax3.set_ylim(0,0.0014)
for p in ax3.patches:    
    annotate_height = p.get_height()+0.0001
    ax3.annotate("{:.6f}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', rotation=90, fontsize=12, color='black', xytext=(0, 20),textcoords='offset points')
p4 = ax4.bar(X_axis+width*1.5, Tx_fee_usd, width, zorder=3, hatch='o', edgecolor='black', color="teal", label='Transaction fee (USD)')

for p in ax4.patches:    
    annotate_height = p.get_height()+0.3
    ax4.annotate("{:.6f}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', rotation=90, fontsize=12, color='black', xytext=(0, 20),textcoords='offset points')
ax4.set_ylim(0,4)
lns = [p1, p2,p3,p4]
ax1.legend(handles=lns, loc='upper center',fontsize=14)
ax1.set_xticks(X_axis)
ax1.set_xticklabels(X, fontsize=12)
ax1.xaxis.set_ticks_position("bottom")
ax1.set_xlabel("Transaction Name - FLTPC on Rinkeby", fontweight='bold', fontsize=12)


plt.show()

# %%
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
import numpy as np
import matplotlib.pyplot as plt



X = ['createFLNFT', 'start_LMSs', 'submitLocalModel', 'close_LMSs','ADRLMS','setLMSADRC','GMupdate']
Gas_Used = [505_401, 60_683, 270_110, 66_038, 87133, 64_149, 175_107 ] 
Gas_Price = [2.000000234, 1.940000008, 2.1428571486, 2.000000256,1.5000000080, 2.500000008  , 1.440000204 ]
Tx_fee_eth = [0.001010802118263834, 0.000117725020485464, 0.0005872333 , 0.000122476015676928, 0.0001518631, 0.000160372500513192, 0.000252154115721828]
Tx_fee_usd = Tx_fee_usd = [m *3250 for m in Tx_fee_eth]


width = 0.2
fig1, ax1 = plt.subplots(figsize=(12,9))
ax1.set_ylabel('Gas Used', fontweight='bold', fontsize=12)
ax1.set_ylim(0,800000)
X_axis = np.arange(len(X))

p1 = ax1.bar(X_axis-width*1.5, Gas_Used, width, zorder=3, hatch='*', edgecolor='black', color="green", label='Gas Used')

for p in ax1.patches:    
    annotate_height = p.get_height()+20000
    ax1.annotate("{:.0f}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', rotation=90, fontsize=12, color='black', xytext=(0, 20),textcoords='offset points')
    
ax2 = ax1.twinx()  
# ax2.spines['left'].set_position(('outward', 70)) 
ax2.set_ylabel('Gas Price (Gwei)', fontweight='bold', fontsize=12)
ax2.set_ylim(1,3)

p2 = ax2.bar(X_axis-width*0.5, Gas_Price, width, zorder=3, hatch='O', edgecolor='black', color="salmon", label='Gas Price')

for p in ax2.patches:    
    annotate_height = p.get_height()+0.1
    ax2.annotate("{:.6f}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', rotation=90, fontsize=12, color='black', xytext=(0, 20),textcoords='offset points')
    
ax3 = ax1.twinx()
ax3.set_ylabel('Transaction fee (ETH)', fontweight='bold', fontsize=12)
ax4 = ax1.twinx()
ax4.set_ylabel('Transaction fee (USD)', fontweight='bold', fontsize=12)
ax3.spines['right'].set_position(('outward', 70))  
ax4.spines['right'].set_position(('outward', 150))  
p3 = ax3.bar(X_axis+width*0.5, Tx_fee_eth, width, zorder=3, hatch='x', edgecolor='black', color="blue", label='Transaction fee (ETH)')
ax3.set_ylim(0,0.0014)
for p in ax3.patches:    
    annotate_height = p.get_height()+0.0001
    ax3.annotate("{:.6f}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', rotation=90, fontsize=12, color='black', xytext=(0, 20),textcoords='offset points')
p4 = ax4.bar(X_axis+width*1.5, Tx_fee_usd, width, zorder=3, hatch='o', edgecolor='black', color="teal", label='Transaction fee (USD)')

for p in ax4.patches:    
    annotate_height = p.get_height()+0.3
    ax4.annotate("{:.6f}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', rotation=90, fontsize=12, color='black', xytext=(0, 20),textcoords='offset points')
ax4.set_ylim(0,4)
lns = [p1, p2,p3,p4]
ax1.legend(handles=lns, loc='upper center',fontsize=14)
ax1.set_xticks(X_axis)
ax1.set_xticklabels(X, fontsize=12)
ax1.xaxis.set_ticks_position("bottom")
ax1.set_xlabel("Transaction Name - FLTPC on Rinkeby", fontweight='bold', fontsize=12)


plt.show()

# %%
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
import numpy as np
import matplotlib.pyplot as plt



X = ['createFLNFT', 'start_LMSs', 'submitLocalModel', 'close_LMSs','ADRLMS','setLMSADRC','GMupdate']
Gas_Used = [505_401, 60_683, 270_110, 66_038, 87133, 64_149, 175_107 ] 
Gas_Price = [2.000000234, 1.940000008, 2.1428571486, 2.000000256,1.5000000080, 2.500000008  , 1.440000204 ]
Tx_fee_eth = [0.001010802118263834, 0.000117725020485464, 0.0005872333 , 0.000122476015676928, 0.0001518631, 0.000160372500513192, 0.000252154115721828]
Tx_fee_usd = Tx_fee_usd = [m *3250 for m in Tx_fee_eth]


width = 0.2
nwidth=width*0.8
fig1, ax1 = plt.subplots(figsize=(12,9))
ax1.set_ylabel('Gas Used', fontweight='bold', fontsize=12)
ax1.set_ylim(0,800000)
X_axis = np.arange(len(X))

p1 = ax1.bar(X_axis-width*1.5, Gas_Used, nwidth, zorder=3, hatch='/', edgecolor='black', color="green", label='Gas Used')

for p in ax1.patches:    
    annotate_height = p.get_height()+20000
    ax1.annotate("{:.0f}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', rotation=90, fontsize=12, color='black', xytext=(0, 20),textcoords='offset points')
    
ax2 = ax1.twinx()  
# ax2.spines['left'].set_position(('outward', 70)) 
ax2.set_ylabel('Gas Price (Gwei)', fontweight='bold', fontsize=12)
ax2.set_ylim(1,3)

p2 = ax2.bar(X_axis-width*0.5, Gas_Price, nwidth, zorder=3, hatch='O', edgecolor='black', color="salmon", label='Gas Price')

for p in ax2.patches:    
    annotate_height = p.get_height()+0.1
    ax2.annotate("{:.6f}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', rotation=90, fontsize=12, color='black', xytext=(0, 20),textcoords='offset points')
    
ax3 = ax1.twinx()
ax3.set_ylabel('Transaction fee (ETH)', fontweight='bold', fontsize=12)
ax4 = ax1.twinx()
ax4.set_ylabel('Transaction fee (USD)', fontweight='bold', fontsize=12)
ax3.spines['right'].set_position(('outward', 70))  
ax4.spines['right'].set_position(('outward', 150))  
p3 = ax3.bar(X_axis+width*0.5, Tx_fee_eth, nwidth, zorder=3, hatch='|', edgecolor='black', color="blue", label='Transaction fee (ETH)')
ax3.set_ylim(0,0.0014)
for p in ax3.patches:    
    annotate_height = p.get_height()+0.0001
    ax3.annotate("{:.6f}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', rotation=90, fontsize=12, color='black', xytext=(0, 20),textcoords='offset points')
p4 = ax4.bar(X_axis+width*1.5, Tx_fee_usd, nwidth, zorder=3, hatch='x', edgecolor='black', color="teal", label='Transaction fee (USD)')

for p in ax4.patches:    
    annotate_height = p.get_height()+0.3
    ax4.annotate("{:.6f}".format(p.get_height()), (p.get_x() + p.get_width() / 2., annotate_height),
                        ha='center', va='center', rotation=90, fontsize=12, color='black', xytext=(0, 20),textcoords='offset points')
ax4.set_ylim(0,4)
lns = [p1, p2,p3,p4]
ax1.legend(handles=lns, loc='upper center',fontsize=16)
ax1.set_xticks(X_axis)
ax1.set_xticklabels(X, fontsize=12)
ax1.xaxis.set_ticks_position("bottom")
ax1.set_xlabel("Transaction Name - FLTPC on Rinkeby", fontweight='bold', fontsize=12)


plt.show()
